# %%
import pandas 
import seaborn
# Out:
# /usr/local/bin/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
f = pandas.read_csv( '../rosetta_runs/benchmark/benchmark_feature_set.csv', index_col=0 )

# %%
nat = f[ ( f.index.str[0] == 'A' ) & ( f.index.str[-1] == 'A' ) ]

# %%
nat.describe()
# Out:
#        total_score      fa_rep    hbond_sc  all_cst  tot_pstat_pm  \
# count   299.000000  299.000000  299.000000    299.0    299.000000
# mean   -689.787759  286.545217  -69.583545      0.0      0.700067
# std       1.326931    0.860107    0.561142      0.0      0.009693
# min    -693.470000  284.420000  -72.030000      0.0      0.670000
# 25%    -690.675000  285.915000  -69.840000      0.0      0.690000
# 50%    -689.890000  286.460000  -69.560000      0.0      0.700000
# 75%    -688.955000  287.020000  -69.280000      0.0      0.710000
# max    -684.960000  290.200000  -66.940000      0.0      0.730000
#
#        tot_nlpstat_pm  tot_burunsat_pm  tot_hbond_pm  tot_NLconts_pm  \
# count      299.000000       299.000000    299.000000      299.000000
# mean         0.696020       151.762542    437.645485      150.812709
# std          0.007086         2.001795      1.135784        1.332998
# min          0.670000       147.000000    435.000000      147.000000
# ...

# %%
f.describe()
# Out:
#         total_score        fa_rep      hbond_sc  all_cst  tot_pstat_pm  \
# count  18880.000000  18880.000000  18880.000000  18880.0  18880.000000
# mean    -630.483296    341.544702    -69.415716      0.0      0.696770
# std      537.782414    535.710777      1.172671      0.0      0.010723
# min     -756.560000    278.630000    -74.620000      0.0      0.660000
# 25%     -690.020000    285.280000    -70.000000      0.0      0.690000
# 50%     -688.320000    286.260000    -69.510000      0.0      0.700000
# 75%     -686.080000    287.330000    -68.750000      0.0      0.700000
# max     6544.710000   7504.730000    -61.830000      0.0      0.740000
#
#        tot_nlpstat_pm  tot_burunsat_pm  tot_hbond_pm  tot_NLconts_pm  \
# count    18880.000000     18880.000000  18880.000000    18880.000000
# mean         0.691531       152.288559    437.172564      150.263400
# std          0.008088         2.938841      1.808687        1.682977
# ...
