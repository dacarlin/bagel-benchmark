# %%
import pandas 
from Bio.SeqUtils import seq1 

foldx_out = pandas.read_csv( 'raw_out.txt', sep='\s+', header=None, names=['name','ddg'] )
foldx_out['my_name'] = foldx_out.name.map( lambda x: '{}{}'.format( seq1(x[:3]),x[4:] ) ) 
foldx_out
# Out:
#         name       ddg my_name
# 0   ALAA192S  0.205420   A192S
# 1   ALAA227W  1.084760   A227W
# 2   CYSA167A  0.981883   C167A
# 3   CYSA167F  2.058170   C167F
# 4   CYSA167Q  1.567400   C167Q
# 5   ASPA322A  0.207347   D322A
# 6   GLUA154D  0.130429   E154D
# 7   GLUA164D  1.450050   E164D
# 8   GLUA164R  0.284931   E164R
# 9   GLUA177K  0.158469   E177K
# 10  GLUA177L  0.381902   E177L
# 11  GLUA222A  0.053367   E222A
# 12  GLUA222K  0.756596   E222K
# 13  GLUA222Q  0.226550   E222Q
# 14  GLUA222R  0.779439   E222R
# 15  GLUA353A  0.694877   E353A
# 16  GLUA388C  0.276947   E388C
# 17  GLUA406A  1.494480   E406A
# 18  GLUA406N  1.080160   E406N
# 19  GLUA406Q  1.165690   E406Q
# 20  HISA119N  1.260060   H119N
# 21  HISA178F  0.789039   H178F
# 22  ILEA244V  1.322220   I244V
# 23  LEUA108N  0.515310   L108N
# 24  LEUA219I  0.321725   L219I
# 25  ASNA163A  0.589523   N163A
# 26  ASNA163C  0.758296   N163C
# 27  ASNA163K  0.088982   N163K
# 28  ASNA220H  0.396954   N220H
# ...

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 

plt.bar( foldx_out.index, foldx_out.ddg )
# Out:
# <Container object of 57 artists>
